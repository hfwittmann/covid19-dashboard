# %%
import pandas as pd

# %%
from subs.getData import getCountries
from subs.getData import getTimeseries
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-4f04a739e260> in <module>
# ----> 1 from subs.getData import getCountries
#       2 from subs.getData import getTimeseries
#
# ImportError: cannot import name 'getCountries' from 'subs.getData' (/app/subs/getData.py)

# %%
res_countries = getCountries()
countries = pd.read_json(res_countries['countries'])
countries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1f9b22a867ea> in <module>
# ----> 1 res_countries = getCountries()
#       2 countries = pd.read_json(res_countries['countries'])
#       3 countries
#
# NameError: name 'getCountries' is not defined

# %%
res_confirmed = getTimeseries('Confirmed')
timeseries_confirmed = pd.read_json(res_confirmed['timeseries'])
timeseries_confirmed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-13ece1cf6704> in <module>
# ----> 1 res_confirmed = getTimeseries('Confirmed')
#       2 timeseries_confirmed = pd.read_json(res_confirmed['timeseries'])
#       3 timeseries_confirmed
#
# NameError: name 'getTimeseries' is not defined

# %%
res_death = getTimeseries('Death')
timeseries_death = pd.read_json(res_death['timeseries'])
timeseries_death
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cc8706f3340d> in <module>
# ----> 1 res_death = getTimeseries('Death')
#       2 timeseries_death = pd.read_json(res_death['timeseries'])
#       3 timeseries_death
#
# NameError: name 'getTimeseries' is not defined

# %%
from subs.data_preprocessing_1 import get_T0
from subs.data_preprocessing_1 import get_T

# %%
country_T0 = get_T0(timeseries_death)
country_T0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-52277e78e61a> in <module>
# ----> 1 country_T0 = get_T0(timeseries_death)
#       2 country_T0
#
# NameError: name 'timeseries_death' is not defined

# %%
get_T(country_T0, timeseries_confirmed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b569c1b95564> in <module>
# ----> 1 get_T(country_T0, timeseries_confirmed)
#
# NameError: name 'country_T0' is not defined

# %%
get_T(country_T0, timeseries_death)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9417180c1aa4> in <module>
# ----> 1 get_T(country_T0, timeseries_death)
#
# NameError: name 'country_T0' is not defined

# %%
from subs.getData import getTimeseries_T

# %%
getTimeseries_T('Death')
# Out:
# {'timeseries_T': '{"country":{"0":"Afghanistan","1":"Afghanistan","2":"Afghanistan","3":"Afghanistan","4":"Afghanistan","5":"Afghanistan","6":"Afghanistan","7":"Afghanistan","8":"Afghanistan","9":"Afghanistan","10":"Afghanistan","11":"Afghanistan","12":"Afghanistan","13":"Afghanistan","14":"Afghanistan","15":"Afghanistan","16":"Afghanistan","17":"Afghanistan","18":"Afghanistan","19":"Afghanistan","20":"Afghanistan","21":"Afghanistan","22":"Afghanistan","23":"Afghanistan","24":"Afghanistan","25":"Afghanistan","26":"Afghanistan","27":"Afghanistan","28":"Afghanistan","29":"Afghanistan","30":"Afghanistan","31":"Afghanistan","32":"Afghanistan","33":"Afghanistan","34":"Afghanistan","35":"Afghanistan","36":"Afghanistan","37":"Afghanistan","38":"Afghanistan","39":"Afghanistan","40":"Afghanistan","41":"Afghanistan","42":"Afghanistan","43":"Afghanistan","44":"Afghanistan","45":"Afghanistan","46":"Afghanistan","47":"Afghanistan","48":"Afghanistan","49":"Afghanistan","50":"Afghanistan","51":"Afg
# ...

# %%
from subs.getData import getTimeseries_T

# %%
getTimeseries_T('Confirmed')
# Out:
# {'timeseries_T': '{"country":{"0":"Afghanistan","1":"Afghanistan","2":"Afghanistan","3":"Afghanistan","4":"Afghanistan","5":"Afghanistan","6":"Afghanistan","7":"Afghanistan","8":"Afghanistan","9":"Afghanistan","10":"Afghanistan","11":"Afghanistan","12":"Afghanistan","13":"Afghanistan","14":"Afghanistan","15":"Afghanistan","16":"Afghanistan","17":"Afghanistan","18":"Afghanistan","19":"Afghanistan","20":"Afghanistan","21":"Afghanistan","22":"Afghanistan","23":"Afghanistan","24":"Afghanistan","25":"Afghanistan","26":"Afghanistan","27":"Afghanistan","28":"Afghanistan","29":"Afghanistan","30":"Afghanistan","31":"Afghanistan","32":"Afghanistan","33":"Afghanistan","34":"Afghanistan","35":"Afghanistan","36":"Afghanistan","37":"Afghanistan","38":"Afghanistan","39":"Afghanistan","40":"Afghanistan","41":"Afghanistan","42":"Afghanistan","43":"Afghanistan","44":"Afghanistan","45":"Afghanistan","46":"Afghanistan","47":"Afghanistan","48":"Afghanistan","49":"Afghanistan","50":"Afghanistan","51":"Afg
# ...

# %%
from subs.getData import getTimeseries

# %%
getTimeseries('Death')
# Out:
# {'timeseries': '{"date":{"0":"2020-01-22","1":"2020-01-23","2":"2020-01-24","3":"2020-01-25","4":"2020-01-26","5":"2020-01-27","6":"2020-01-28","7":"2020-01-29","8":"2020-01-30","9":"2020-01-31","10":"2020-02-01","11":"2020-02-02","12":"2020-02-03","13":"2020-02-04","14":"2020-02-05","15":"2020-02-06","16":"2020-02-07","17":"2020-02-08","18":"2020-02-09","19":"2020-02-10","20":"2020-02-11","21":"2020-02-12","22":"2020-02-13","23":"2020-02-14","24":"2020-02-15","25":"2020-02-16","26":"2020-02-17","27":"2020-02-18","28":"2020-02-19","29":"2020-02-20","30":"2020-02-21","31":"2020-02-22","32":"2020-02-23","33":"2020-02-24","34":"2020-02-25","35":"2020-02-26","36":"2020-02-27","37":"2020-02-28","38":"2020-02-29","39":"2020-03-01","40":"2020-03-02","41":"2020-03-03","42":"2020-03-04","43":"2020-03-05","44":"2020-03-06","45":"2020-03-07","46":"2020-03-08","47":"2020-03-09","48":"2020-03-10","49":"2020-03-11","50":"2020-03-12","51":"2020-03-13","52":"2020-03-14","53":"2020-03-15","54":"2020-
# ...

# %%
from subs.data_preprocessing_0 import load_timeseries

# %%
load_timeseries('Death')
# Out:
#             date      country   type  cases CODE
# 0     2020-01-22  Afghanistan  death      0  AFG
# 1     2020-01-23  Afghanistan  death      0  AFG
# 2     2020-01-24  Afghanistan  death      0  AFG
# 3     2020-01-25  Afghanistan  death      0  AFG
# 4     2020-01-26  Afghanistan  death      0  AFG
# ...          ...          ...    ...    ...  ...
# 9995  2021-02-23     Botswana  death    300  BWA
# 9996  2021-02-24     Botswana  death    300  BWA
# 9997  2021-02-25     Botswana  death    310  BWA
# 9998  2021-02-26     Botswana  death    310  BWA
# 9999  2021-02-27     Botswana  death    310  BWA
#
# [10000 rows x 5 columns]
